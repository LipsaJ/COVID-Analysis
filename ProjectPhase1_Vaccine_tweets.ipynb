# %% [markdown]
# ### Project Phase 1
# #### Collect Vaccine related tweets

# %% [markdown]
# Import required packages

# %%
import tweepy
import json
import csv
import pandas as pd
import os

# %% [markdown]
# Twitter data collection set up

# %%
# Function to read the key file and load keys in a dictionary
def loadKeys(key_file):
    with open(key_file) as f:
        key_dict = json.load(f)
    return key_dict['api_key'], key_dict['api_secret'], key_dict['token'], key_dict['token_secret']

KEY_FILE = 'keys.json'
api_key, api_secret, token, token_secret = loadKeys(KEY_FILE)
auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(token, token_secret)
api = tweepy.API(auth)

# %%
file = 'vaccinetweets.csv'
if(os.path.exists(file) and os.path.isfile(file)): 
  os.remove(file) 
  print("file deleted") 
else: 
  print("file not found")
# Out:
# file deleted

# %%
csvFile = open('vaccinetweets.csv', 'a')
#Use csv writer
csvWriter = csv.writer(csvFile)

# %% [markdown]
# Saving the tweets in the CSV file

# %%
search_term = "Vaccine OR vaccine against coronavirus OR Vaccines work OR Covid Vaccine OR #vaccine2021"

new_search = search_term 

for page in tweepy.Cursor(api.search, wait_on_rate_limit=True, q = new_search, lang="en",tweet_mode="extended",since="2021-02-22").pages():
    for status in page:
        csvWriter.writerow([status.id ,status.user.name , status.full_text,status.entities , status.retweet_count, status.favorite_count, status.created_at])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-cd92384c2492> in <module>
#       3 new_search = search_term
#       4
# ----> 5 for page in tweepy.Cursor(api.search, wait_on_rate_limit=True, q = new_search, lang="en",tweet_mode="extended",since="2021-02-22").pages():
#       6     for status in page:
#       7         csvWriter.writerow([status.id ,status.user.name , status.full_text,status.entities , status.retweet_count, status.favorite_count, status.created_at])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/cursor.py in __next__(self)
#      49
#      50     def __next__(self):
# ---> 51         return self.next()
#      52
#      53     def next(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/cursor.py in next(self)
#     130
#     131         if self.index >= len(self.results) - 1:
# --> 132             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     133
#     134             if hasattr(self.method, '__self__'):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/binder.py in execute(self)
#     161                                     if self.wait_on_rate_limit_notify:
#     162                                         log.warning("Rate limit reached. Sleeping for: %d" % sleep_time)
# --> 163                                     time.sleep(sleep_time + 5)  # sleep for few extra sec
#     164
#     165                 # if self.wait_on_rate_limit and self._reset_time is not None and \
#
# KeyboardInterrupt:

# %% [markdown]
# Checking the total tweets collected

# %%
file = open("vaccinetweets.csv")
reader = csv.reader(file)
lines= len(list(reader))
print("The number of rows in the files are:",lines)
# Out:
# The number of rows in the files are: 20092

# %%
df_cols = ['t_id','user_name','tweet', 'entities', 'retweet_count', 'favorite_count','datetime'] 
df = pd.read_csv("vaccinetweets.csv", header=None, names = df_cols)

# %% [markdown]
# Basic inspection of the dataframe

# %%
df.head()
# Out:
#                   t_id          user_name  \
# 0  1363585788303335425    Jeremy Kagan 🇺🇸
# 1  1363585640546242560           Kathleen
# 2  1363585138324627456   Bruno J. Navarro
# 3  1363585027515158528           GG Cares
# 4  1363584167032877057  Madeleine Fullard
#
#                                                tweet  \
# 0  RT @NBCNews: “What we are going to see is a ca...
# 1  RT @CNNSotu: "The vaccines that we are current...
# 2  RT @NBCNews: “What we are going to see is a ca...
# 3  RT @handgunYoga: @lifeisgnarly @djrothkopf cor...
# 4  RT @NBCNews: “What we are going to see is a ca...
#
#                                             entities  retweet_count  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...             18
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...            136
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...             18
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...              1
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...             18
#
#    favorite_count             datetime
# 0               0  2021-02-21 20:26:00
# 1               0  2021-02-21 20:25:25
# 2               0  2021-02-21 20:23:25
# 3               0  2021-02-21 20:22:59
# 4               0  2021-02-21 20:19:34

# %%
df.tail()
# Out:
#                       t_id     user_name  \
# 20087  1363838370607099905       vaghela
# 20088  1363838304895053829    Ashe Short
# 20089  1363838040188227586  Arti makhija
# 20090  1363837986480136196    @meensjaya
# 20091  1363837923670384644          Anna
#
#                                                    tweet  \
# 20087  vaccine refrigerators from \n\n@GodrejApplianc...
# 20088  RT @politicalmath: fwiw, we are about to get a...
# 20089  RT @ImBhaumil: Three cheers to @GodrejApplianc...
# 20090  RT @ImBhaumil: Three cheers to @GodrejApplianc...
# 20091  RT @ImBhaumil: Three cheers to @GodrejApplianc...
#
#                                                 entities  retweet_count  \
# 20087  {'hashtags': [{'text': 'GodrejForVaccineProtec...              0
# 20088  {'hashtags': [], 'symbols': [], 'user_mentions...             27
# 20089  {'hashtags': [], 'symbols': [], 'user_mentions...            111
# 20090  {'hashtags': [], 'symbols': [], 'user_mentions...            111
# 20091  {'hashtags': [], 'symbols': [], 'user_mentions...            111
#
#        favorite_count             datetime
# 20087               1  2021-02-22 13:09:41
# 20088               0  2021-02-22 13:09:25
# 20089               0  2021-02-22 13:08:22
# 20090               0  2021-02-22 13:08:09
# 20091               0  2021-02-22 13:07:54

# %%
df.iloc[[15000]]
# Out:
#                       t_id          user_name  \
# 15000  1364923204603674625  Dr. Joseph Frusci
#
#                                                    tweet  \
# 15000  NEW: Pfizer and BioNTech announced they have l...
#
#                                                 entities  retweet_count  \
# 15000  {'hashtags': [], 'symbols': [], 'user_mentions...              0
#
#        favorite_count             datetime
# 15000               0  2021-02-25 13:00:25

# %%
df1 = df.sample(3000)
df1 = df1.reset_index()

# %%
df1
# Out:
#       index                 t_id              user_name  \
# 0      2356  1362456615484612612                   Luba
# 1      5941  1361424542338404352          Charlea Moore
# 2     18384  1364571354805067776       kashyap vaishnav
# 3      4111  1362166121940541441            Bee Hawkins
# 4     19370  1364144650403999749             Miyaki Lee
# ...     ...                  ...                    ...
# 2995  16107  1364686807493828609  Jolene Chishipomjapug
# 2996  18198  1364577687428345859           Anne(@🏡) LLB
# 2997    935  1363064929767600129            Marco Alves
# 2998  18190  1364578034976776200           Ed Buttaccio
# 2999  11810  1365658846639886338            mcatat beta
#
#                                                   tweet  \
# 0     RT @OOrlova: A laboratory study suggests that ...
# 1     RT @AP: The makers of COVID-19 vaccines are fi...
# 2     Coronavirus Essential :&gt;  India's COVID-19 ...
# 3     RT @Reuters: Israeli study finds Pfizer vaccin...
# 4     RT @VaticanNews: The President of Argentina’s ...
# ...                                                 ...
# 2995  RT @WSJ: Moderna said its new Covid-19 vaccine...
# 2996  RT @AP: An analysis by U.S. regulators says Jo...
# 2997  “I can’t emphasise enough how outrageous it is...
# 2998  RT @AP: An analysis by U.S. regulators says Jo...
# 2999  RT @CNN: A third vaccine is poised to join the...
#
#                                                entities  retweet_count  \
# 0     {'hashtags': [], 'symbols': [], 'user_mentions...              2
# 1     {'hashtags': [], 'symbols': [], 'user_mentions...             80
# 2     {'hashtags': [], 'symbols': [], 'user_mentions...              0
# 3     {'hashtags': [], 'symbols': [], 'user_mentions...             64
# 4     {'hashtags': [], 'symbols': [], 'user_mentions...             18
# ...                                                 ...            ...
# 2995  {'hashtags': [], 'symbols': [], 'user_mentions...             68
# 2996  {'hashtags': [], 'symbols': [], 'user_mentions...           1816
# 2997  {'hashtags': [], 'symbols': [], 'user_mentions...              1
# 2998  {'hashtags': [], 'symbols': [], 'user_mentions...           1816
# 2999  {'hashtags': [], 'symbols': [], 'user_mentions...            139
#
#       favorite_count             datetime
# 0                  0  2021-02-18 17:39:05
# 1                  0  2021-02-15 21:17:59
# 2                  0  2021-02-24 13:42:18
# 3                  0  2021-02-17 22:24:45
# 4                  0  2021-02-23 09:26:43
# ...              ...                  ...
# 2995               0  2021-02-24 21:21:04
# 2996               0  2021-02-24 14:07:27
# 2997               4  2021-02-20 09:56:18
# 2998               0  2021-02-24 14:08:50
# 2999               0  2021-02-27 13:43:36
#
# [3000 rows x 8 columns]
